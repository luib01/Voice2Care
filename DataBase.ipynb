# %%
import os
import json

from datetime import datetime
from pymongo import MongoClient
from pymongo.errors import PyMongoError

# Configurazione MongoDB
MONGO_URI = "mongodb://localhost:27017"
DB_NAME = "cartella_clinica_db"
COLLECTION_NAME = "interventi"

# Cartella contenente i file JSON
JSON_FOLDER = "./cartella_clinica"

# Connessione a MongoDB
client = MongoClient(MONGO_URI)
db = client[DB_NAME]
collection = db[COLLECTION_NAME]

# Conta i file caricati
inseriti = 0
skippati = 0

# Inserimento dei file JSON
for filename in os.listdir(JSON_FOLDER):
    if filename.endswith(".json"):
        filepath = os.path.join(JSON_FOLDER, filename)
        try:
            with open(filepath, "r", encoding="utf-8") as f:
                data = json.load(f)
                if isinstance(data, dict):  # Assicura che sia un oggetto JSON
                    collection.insert_one(data)
                    inseriti += 1
                else:
                    print(f"[⚠️] File non valido (non è un oggetto JSON): {filename}")
                    skippati += 1
        except (json.JSONDecodeError, PyMongoError) as e:
            print(f" Errore nel file {filename}: {e}")
            skippati += 1

print(f"\n Inserimento completato: {inseriti} file caricati, {skippati} file scartati.")
# Out:
#  Inserimento completato: 19 file caricati, 0 file scartati.

# %%
from pymongo import MongoClient
from pprint import pprint  # Per una stampa leggibile

# Connessione a MongoDB locale
client = MongoClient("mongodb://localhost:27017")

# Accesso al database e alla collezione
db = client["cartella_clinica_db"]
collection = db["interventi"]

# Estrazione e stampa di tutti i documenti
for doc in collection.find():
    pprint(doc)
# Out:
# {'_id': ObjectId('684ed98b7a26fd46f566f36f'),
#  'accesso_venoso': None,
#  'allergie': 'nessuna nota',
#  'cap': '40121',
#  'citta': 'Bologna',
#  'citta_residenza': 'Bologna',
#  'codice_fiscale': 'BNCLRA96C54A944P',
#  'codice_rientro': 'D3',
#  'codice_uscita': 'D3',
#  'cognome_chiamante': 'Bianchi',
#  'cognome_nome_paziente': 'Bianchi Laura',
#  'condizioni_consegna': 'vigile, collaborante, stabile',
#  'data': '2025-06-15',
#  'data_nascita': '1996-03-14',
#  'decesso_sul_posto': False,
#  'dolore_localizzato': 'polso sinistro',
#  'eta': '29 anni',
#  'farmaci_assunti': 'nessuno',
#  'farmaci_somministrati': [],
#  'firma_responsabile': 'M. Galli',
#  'flusso_ossigeno': None,
#  "forze_dell'ordine_presenti": False,
#  'immobilizzazioni': 'steccatura polso sinistro',
#  'indirizzo_intervento': 'via Manzoni 5, Bologna',
#  'indirizzo_residenza': 'via Verdi 12',
#  'luogo_nascita': 'Bologna',
#  'mezzo_trasporto': 'ambulanza',
#  'monitoraggio_continuo': 'monitoraggio parametri vitali durante trasporto',
#  'nome_chiamante': 'Marco Bianchi',
#  'nome_soccorritore_1': 'Giulia Rossi',
#  'nome_soccorritore_2': 'Luca Ferri',
#  'nome_soccorritore_3': 'Marco Galli',
#  'note_intervento': 'Paziente cosciente con trauma polso sinistro da caduta. '
#                     'Steccatura effettuata, medicati tagli al volto. '
#                     'Monitoraggio stabile durante trasporto. Paziente affidata '
#                     'al PS per approfondimenti diagnostici.',
#  'numero_civico': '5',
#  'numero_intervento': 'PR135',
#  'ora_arrivo_ps': '10:25',
#  'ora_arrivo_sul_posto': '09:55',
#  'ora_chiamata': '09:45',
#  'ora_partenza_ambulanza': '09:48',
#  'ora_partenza_dal_posto': '10:10',
#  'ora_rientro_sede': '10:50',
#  'ospedale_destinazione': 'Ospedale Maggiore, Bologna',
#  'ossigenoterapia': False,
#  'parametri_vitali': [{'AVPU': 'vigile',
#                        'ECG': 'non eseguito',
#                        'frequenza_cardiaca': '90 bpm',
#                        'frequenza_respiratoria': '18 atti/min',
#                        'glicemia': '95 mg/dL',
#                        'pressione_arteriosa': '120/75',
#                        'pupille_PEARL': 'isocoriche, reagenti',
#                        'saturazione_ossigeno': '98%',
#                        'temperatura': '36.5°C',
#                        'tempo_rilevazione': '09:57'}],
#  'patologie_pregresse': 'nessuna',
#  'paziente_consegnato_ps': True,
#  'paziente_rifiuto_trasporto': False,
#  'posizionamento_paziente': 'seduta',
#  'problemi_riscontrati': 'nessuno',
#  'provincia': 'BO',
#  'provincia_nascita': 'BO',
#  'provincia_residenza': 'BO',
#  'relazione_con_paziente': 'fratello',
#  'reparto_destinazione': 'Pronto Soccorso',
#  'residenza': 'via Verdi 12, Bologna',
#  'ruolo_soccorritore_1': 'infermiere',
#  'ruolo_soccorritore_2': 'autista soccorritore',
#  'ruolo_soccorritore_3': 'capo equipaggio',
#  'sesso': 'femminile',
#  'sintomi': ['dolore acuto al polso sinistro',
#              'abrasioni al volto',
#              'agitazione'],
#  'soluzione_endovenosa': None,
#  'stato_coscienza': 'vigile e orientata',
#  'telefono_chiamante': '051-1234567',
#  'tipo_mezzo': 'ambulanza',
#  'via': 'via Manzoni'}
# {'_id': ObjectId('684ed98b7a26fd46f566f370'),
#  'accesso_venoso': None,
#  'allergie': None,
#  'cap': '',
#  'citta': 'Parma',
#  'citta_residenza': None,
#  'codice_fiscale': None,
#  'codice_rientro': 'D4',
#  'codice_uscita': 'D2',
#  'cognome_chiamante': '',
#  'cognome_nome_paziente': None,
#  'condizioni_consegna': '',
#  'data': '',
#  'data_nascita': None,
#  'decesso_sul_posto': False,
#  'dolore_localizzato': 'addome',
#  'eta': 'circa 35 anni',
#  'farmaci_assunti': None,
#  'farmaci_somministrati': [],
#  'firma_responsabile': '',
#  'flusso_ossigeno': None,
#  "forze_dell'ordine_presenti": None,
#  'immobilizzazioni': None,
#  'indirizzo_intervento': 'via Verdi 10, Parma',
#  'indirizzo_residenza': None,
#  'luogo_nascita': '',
#  'mezzo_trasporto': 'ambulanza',
#  'monitoraggio_continuo': '',
#  'nome_chiamante': '',
#  'nome_soccorritore_1': '',
#  'nome_soccorritore_2': '',
#  'nome_soccorritore_3': '',
#  'note_intervento': 'Posizionato in sicurezza con mantenimento della posizione '
#                     'antalgica, assistito durante i conati e monitorato per la '
#                     'pervietà delle vie aeree. Iniziato monitoraggio dei '
#                     'parametri vitali. Raccolta anamnesi sul posto, richiesto '
#                     'trasporto in codice giallo verso Pronto Soccorso per '
#                     'sospetta intossicazione alimentare.',
#  'numero_civico': '10',
#  'numero_intervento': 'PR125',
#  'ora_arrivo_ps': None,
#  'ora_arrivo_sul_posto': None,
#  'ora_chiamata': '11:08',
#  'ora_partenza_ambulanza': None,
#  'ora_partenza_dal_posto': None,
#  'ora_rientro_sede': None,
#  'ospedale_destinazione': None,
#  'ossigenoterapia': None,
#  'parametri_vitali': [{'AVPU': 'vigile e orientato',
#                        'ECG': '',
#                        'frequenza_cardiaca': '<100 bpm',
#                        'frequenza_respiratoria': '>25 atti al minuto',
#                        'glicemia': None,
#                        'pressione_arteriosa': '',
#                        'pupille_PEARL': '',
#                        'saturazione_ossigeno': None,
#                        'temperatura': None,
#                        'tempo_rilevazione': ''}],
#  'patologie_pregresse': None,
#  'paziente_consegnato_ps': True,
#  'paziente_rifiuto_trasporto': False,
#  'posizionamento_paziente': 'posizione antalgica',
#  'problemi_riscontrati': '',
#  'provincia': '',
#  'provincia_nascita': '',
#  'provincia_residenza': None,
#  'relazione_con_paziente': '',
#  'reparto_destinazione': 'Pronto Soccorso',
#  'residenza': None,
#  'ruolo_soccorritore_1': '',
#  'ruolo_soccorritore_2': '',
#  'ruolo_soccorritore_3': '',
#  'sesso': 'maschile',
#  'sintomi': ['forti dolori addominali',
#              'nausea intensa',
#              'ripetuti episodi di vomito'],
#  'soluzione_endovenosa': None,
#  'stato_coscienza': 'vigile e orientato',
#  'telefono_chiamante': '0521‑000002',
#  'tipo_mezzo': 'ambulanza',
#  'via': 'via Verdi'}
# {'_id': ObjectId('684ed98b7a26fd46f566f371'),
#  'accesso_venoso': True,
#  'allergie': 'allergica a penicillina',
#  'cap': '43036',
#  'citta': 'Fidenza',
#  'citta_residenza': 'Fidenza',
#  'codice_fiscale': 'FRRMRN47S48D548X',
#  'codice_rientro': 'D3',
#  'codice_uscita': 'D1',
#  'cognome_chiamante': 'Ferrari',
#  'cognome_nome_paziente': 'Ferrari Maria',
#  'condizioni_consegna': 'saturazione migliorata, paziente ancora confusa ma '
#                         'stabilizzata',
#  'data': '2025-06-15',
#  'data_nascita': '1947-11-08',
#  'decesso_sul_posto': False,
#  'dolore_localizzato': 'nessuno riferito',
#  'eta': '78 anni',
#  'farmaci_assunti': 'ramipril, broncodilatatori',
#  'farmaci_somministrati': [],
#  'firma_responsabile': 'F. Leoni',
#  'flusso_ossigeno': '6 L/min',
#  "forze_dell'ordine_presenti": False,
#  'immobilizzazioni': None,
#  'indirizzo_intervento': 'via Montale 22, Fidenza',
#  'indirizzo_residenza': 'via Verga 5',
#  'luogo_nascita': 'Fidenza',
#  'mezzo_trasporto': 'ambulanza',
#  'monitoraggio_continuo': 'parametri monitorati costantemente, miglioramento '
#                           'progressivo saturazione',
#  'nome_chiamante': 'Laura',
#  'nome_soccorritore_1': 'Sara Conti',
#  'nome_soccorritore_2': 'Francesco Leoni',
#  'nome_soccorritore_3': 'Martina Rossi',
#  'note_intervento': 'Paziente di 78 anni trovata all’interno della propria '
#                     'abitazione in stato confusionale, con segni di difficoltà '
#                     'respiratoria. La figlia ha riferito insorgenza improvvisa '
#                     'dei sintomi. Paziente collaborante ma disorientata. '
#                     'Saturazione iniziale 89%, avviata ossigenoterapia con '
#                     'miglioramento progressivo. Posizionato accesso venoso e '
#                     'infusa fisiologica in infusione lenta. Monitoraggio '
#                     'continuo durante il trasporto in codice rosso verso '
#                     'l’Ospedale di Fidenza. Consegnata in PS con condizioni in '
#                     'leggero miglioramento.',
#  'numero_civico': '22',
#  'numero_intervento': 'PR126',
#  'ora_arrivo_ps': '09:24',
#  'ora_arrivo_sul_posto': '08:53',
#  'ora_chiamata': '08:42',
#  'ora_partenza_ambulanza': '08:45',
#  'ora_partenza_dal_posto': '09:08',
#  'ora_rientro_sede': '09:50',
#  'ospedale_destinazione': 'Ospedale di Fidenza',
#  'ossigenoterapia': True,
#  'parametri_vitali': [{'AVPU': 'confusa',
#                        'ECG': 'non eseguito',
#                        'frequenza_cardiaca': '110 bpm',
#                        'frequenza_respiratoria': '30 atti/min',
#                        'glicemia': '132 mg/dL',
#                        'pressione_arteriosa': '90/60',
#                        'pupille_PEARL': 'presenti, isocoriche, reagenti',
#                        'saturazione_ossigeno': '89%',
#                        'temperatura': '36.8°C',
#                        'tempo_rilevazione': '08:55'}],
#  'patologie_pregresse': 'BPCO, ipertensione',
#  'paziente_consegnato_ps': True,
#  'paziente_rifiuto_trasporto': False,
#  'posizionamento_paziente': 'semi-seduta',
#  'problemi_riscontrati': 'nessuno',
#  'provincia': 'PR',
#  'provincia_nascita': 'PR',
#  'provincia_residenza': 'PR',
#  'relazione_con_paziente': 'figlia',
#  'reparto_destinazione': 'Pronto Soccorso',
#  'residenza': 'via Verga 5, Fidenza',
#  'ruolo_soccorritore_1': 'autista soccorritore',
#  'ruolo_soccorritore_2': 'capo equipaggio',
#  'ruolo_soccorritore_3': 'soccorritore',
#  'sesso': 'femminile',
#  'sintomi': ['difficoltà respiratoria', 'pallore', 'confusione mentale'],
#  'soluzione_endovenosa': 'soluzione fisiologica 0.9% 250 ml',
#  'stato_coscienza': 'confusa',
#  'telefono_chiamante': '0524‑003344',
#  'tipo_mezzo': 'ambulanza',
#  'via': 'via Montale'}
# {'_id': ObjectId('684ed98b7a26fd46f566f372'),
#  'accesso_venoso': 'posizionato accesso venoso periferico',
#  'allergie': 'penicillina',
#  'cap': '20121',
#  'citta': 'Milano',
#  'citta_residenza': 'Milano',
#  'codice_fiscale': 'RSSGVN53S05F205X',
#  'codice_rientro': 'D4',
#  'codice_uscita': 'D3',
#  'cognome_chiamante': 'Rossi',
#  'cognome_nome_paziente': 'Rossi Giovanni',
#  'condizioni_consegna': 'condizioni stabili ma monitorate',
#  'data': '2025-06-15',
#  'data_nascita': '1953-11-05',
#  'decesso_sul_posto': False,
#  'dolore_localizzato': 'torace',
#  'eta': '72 anni',
#  'farmaci_assunti': ['beta-bloccanti', 'anticoagulanti'],
#  'farmaci_somministrati': [],
#  'firma_responsabile': 'L. Bianchi',
#  'flusso_ossigeno': '4 L/min',
#  "forze_dell'ordine_presenti": False,
#  'immobilizzazioni': None,
#  'indirizzo_intervento': 'via Dante 22, Milano',
#  'indirizzo_residenza': 'via Verdi 45',
#  'luogo_nascita': 'Milano',
#  'mezzo_trasporto': 'ambulanza',
#  'monitoraggio_continuo': 'monitoraggio costante durante trasporto',
#  'nome_chiamante': 'Maria Rossi',
#  'nome_soccorritore_1': 'Anna Verdi',
#  'nome_soccorritore_2': 'Paolo Neri',
#  'nome_soccorritore_3': 'Luca Bianchi',
#  'note_intervento': 'Paziente con malore improvviso e bradicardia, '
#                     'somministrata ossigenoterapia e posizionato accesso '
#                     'venoso. Monitoraggio continuo fino all’arrivo in PS. '
#                     'Trasporto in codice giallo per approfondimenti.',
#  'numero_civico': '22',
#  'numero_intervento': 'PR140',
#  'ora_arrivo_ps': '15:10',
#  'ora_arrivo_sul_posto': '14:40',
#  'ora_chiamata': '14:30',
#  'ora_partenza_ambulanza': '14:33',
#  'ora_partenza_dal_posto': '14:55',
#  'ora_rientro_sede': '15:45',
#  'ospedale_destinazione': 'Ospedale San Raffaele, Milano',
#  'ossigenoterapia': True,
#  'parametri_vitali': [{'AVPU': 'risponde solo a stimoli verbali',
#                        'ECG': 'bradicardia con fibrillazione atriale',
#                        'frequenza_cardiaca': '45 bpm',
#                        'frequenza_respiratoria': '28 atti/min',
#                        'glicemia': '110 mg/dL',
#                        'pressione_arteriosa': '85/60',
#                        'pupille_PEARL': 'isocoriche, reagenti',
#                        'saturazione_ossigeno': '89%',
#                        'temperatura': '36.7°C',
#                        'tempo_rilevazione': '14:42'}],
#  'patologie_pregresse': ['ipertensione', 'fibrillazione atriale'],
#  'paziente_consegnato_ps': True,
#  'paziente_rifiuto_trasporto': False,
#  'posizionamento_paziente': 'semi-seduta',
#  'problemi_riscontrati': 'nessuno',
#  'provincia': 'MI',
#  'provincia_nascita': 'MI',
#  'provincia_residenza': 'MI',
#  'relazione_con_paziente': 'moglie',
#  'reparto_destinazione': 'Pronto Soccorso',
#  'residenza': 'via Verdi 45, Milano',
#  'ruolo_soccorritore_1': 'infermiere',
#  'ruolo_soccorritore_2': 'autista soccorritore',
#  'ruolo_soccorritore_3': 'capo equipaggio',
#  'sesso': 'maschile',
#  'sintomi': ['difficoltà respiratoria', 'sudorazione intensa', 'confusione'],
#  'soluzione_endovenosa': 'soluzione fisiologica',
#  'stato_coscienza': 'semicosciente, confuso',
#  'telefono_chiamante': '02-7654321',
#  'tipo_mezzo': 'ambulanza',
#  'via': 'via Dante'}
# {'_id': ObjectId('684ed98b7a26fd46f566f373'),
#  'accesso_venoso': None,
#  'allergie': None,
#  'cap': None,
#  'citta': 'Modena',
#  'citta_residenza': 'Modena',
#  'codice_fiscale': None,
#  'codice_rientro': 'D3',
#  'codice_uscita': 'D2',
#  'cognome_chiamante': None,
#  'cognome_nome_paziente': 'Luca Bianchi',
#  'condizioni_consegna': '',
#  'data': '',
#  'data_nascita': '20/07/1983',
#  'decesso_sul_posto': False,
#  'dolore_localizzato': 'articolazioni',
#  'eta': None,
#  'farmaci_assunti': None,
#  'farmaci_somministrati': [],
#  'firma_responsabile': '',
#  'flusso_ossigeno': None,
#  "forze_dell'ordine_presenti": None,
#  'immobilizzazioni': None,
#  'indirizzo_intervento': '',
#  'indirizzo_residenza': '',
#  'luogo_nascita': None,
#  'mezzo_trasporto': 'ambulanza',
#  'monitoraggio_continuo': None,
#  'nome_chiamante': None,
#  'nome_soccorritore_1': None,
#  'nome_soccorritore_2': None,
#  'nome_soccorritore_3': None,
#  'note_intervento': 'crisi epilettica, protetto il capo e posizionato in '
#                     'posizione laterale di sicurezza, supporto psicologico in '
#                     'corso',
#  'numero_civico': '15',
#  'numero_intervento': 'MO456',
#  'ora_arrivo_ps': None,
#  'ora_arrivo_sul_posto': None,
#  'ora_chiamata': '14:17',
#  'ora_partenza_ambulanza': None,
#  'ora_partenza_dal_posto': None,
#  'ora_rientro_sede': None,
#  'ospedale_destinazione': 'Policlinico di Modena',
#  'ossigenoterapia': True,
#  'parametri_vitali': [{'AVPU': 'inizialmente incosciente, ora risponde a '
#                                'stimoli verbali e confuso',
#                        'ECG': None,
#                        'frequenza_cardiaca': 'oltre 100 bpm',
#                        'frequenza_respiratoria': 'oltre 25 atti al minuto',
#                        'glicemia': None,
#                        'pressione_arteriosa': None,
#                        'pupille_PEARL': 'reagenti',
#                        'saturazione_ossigeno': None,
#                        'temperatura': None,
#                        'tempo_rilevazione': None}],
#  'patologie_pregresse': None,
#  'paziente_consegnato_ps': True,
#  'paziente_rifiuto_trasporto': False,
#  'posizionamento_paziente': 'posizione laterale di sicurezza',
#  'problemi_riscontrati': '',
#  'provincia': None,
#  'provincia_nascita': None,
#  'provincia_residenza': None,
#  'relazione_con_paziente': None,
#  'reparto_destinazione': None,
#  'residenza': '',
#  'ruolo_soccorritore_1': None,
#  'ruolo_soccorritore_2': None,
#  'ruolo_soccorritore_3': None,
#  'sesso': None,
#  'sintomi': ['crisi tonica e clonica (fasi convulsive)',
#              'tachipnea',
#              'respiro affaticato con tendenza a russare',
#              'polso tachicardico',
#              'dolore alle articolazioni'],
#  'soluzione_endovenosa': None,
#  'stato_coscienza': 'inizialmente incosciente, ora risponde a stimoli verbali '
#                     'e confuso',
#  'telefono_chiamante': '059-000111',
#  'tipo_mezzo': 'ambulanza',
#  'via': 'Verdi'}
# {'_id': ObjectId('684ed98b7a26fd46f566f374'),
#  'accesso_venoso': None,
#  'allergie': '',
#  'cap': '',
#  'citta': 'Parma',
#  'citta_residenza': None,
#  'codice_fiscale': '',
#  'codice_rientro': 'D4',
#  'codice_uscita': 'D3',
#  'cognome_chiamante': '',
#  'cognome_nome_paziente': '',
#  'condizioni_consegna': None,
#  'data': '',
#  'data_nascita': None,
#  'decesso_sul_posto': False,
#  'dolore_localizzato': None,
#  'eta': 'circa 40 anni',
#  'farmaci_assunti': '',
#  'farmaci_somministrati': [],
#  'firma_responsabile': '',
#  'flusso_ossigeno': None,
#  "forze_dell'ordine_presenti": None,
#  'immobilizzazioni': None,
#  'indirizzo_intervento': 'via Garibaldi 18, Parma',
#  'indirizzo_residenza': None,
#  'luogo_nascita': None,
#  'mezzo_trasporto': 'ambulanza PR124',
#  'monitoraggio_continuo': 'sì',
#  'nome_chiamante': '',
#  'nome_soccorritore_1': '',
#  'nome_soccorritore_2': '',
#  'nome_soccorritore_3': '',
#  'note_intervento': '',
#  'numero_civico': '18',
#  'numero_intervento': '',
#  'ora_arrivo_ps': None,
#  'ora_arrivo_sul_posto': None,
#  'ora_chiamata': '15:22',
#  'ora_partenza_ambulanza': None,
#  'ora_partenza_dal_posto': None,
#  'ora_rientro_sede': None,
#  'ospedale_destinazione': '',
#  'ossigenoterapia': None,
#  'parametri_vitali': [{'AVPU': 'vigile',
#                        'ECG': '',
#                        'frequenza_cardiaca': '80 bpm',
#                        'frequenza_respiratoria': '16 atti al minuto',
#                        'glicemia': None,
#                        'pressione_arteriosa': None,
#                        'pupille_PEARL': '',
#                        'saturazione_ossigeno': None,
#                        'temperatura': None,
#                        'tempo_rilevazione': None}],
#  'patologie_pregresse': '',
#  'paziente_consegnato_ps': True,
#  'paziente_rifiuto_trasporto': False,
#  'posizionamento_paziente': 'seduto',
#  'problemi_riscontrati': '',
#  'provincia': '',
#  'provincia_nascita': None,
#  'provincia_residenza': None,
#  'relazione_con_paziente': None,
#  'reparto_destinazione': 'Pronto Soccorso',
#  'residenza': None,
#  'ruolo_soccorritore_1': '',
#  'ruolo_soccorritore_2': '',
#  'ruolo_soccorritore_3': '',
#  'sesso': 'maschile',
#  'sintomi': ['episodi di vomito',
#              'andatura instabile',
#              'parlata sbiascicata',
#              'nausea',
#              'agitazione verbale',
#              'stato confusionale'],
#  'soluzione_endovenosa': None,
#  'stato_coscienza': 'vigile',
#  'telefono_chiamante': '0521‑000001',
#  'tipo_mezzo': 'ambulanza PR124',
#  'via': 'via Garibaldi'}
# {'_id': ObjectId('684ed98b7a26fd46f566f375'),
#  'accesso_venoso': 'posizionato accesso venoso periferico',
#  'allergie': 'penicillina',
#  'cap': '50123',
#  'citta': 'Firenze',
#  'citta_residenza': 'Firenze',
#  'codice_fiscale': 'BNCLRA97B51D612Y',
#  'codice_rientro': 'D4',
#  'codice_uscita': 'D3',
#  'cognome_chiamante': 'Bianchi',
#  'cognome_nome_paziente': 'Bianchi Laura',
#  'condizioni_consegna': 'condizioni stabili, monitoraggio in corso',
#  'data': '2025-06-15',
#  'data_nascita': '1997-02-11',
#  'decesso_sul_posto': False,
#  'dolore_localizzato': 'nessuno',
#  'eta': '28 anni',
#  'farmaci_assunti': None,
#  'farmaci_somministrati': ['adrenalina intramuscolo'],
#  'firma_responsabile': 'F. Martini',
#  'flusso_ossigeno': '6 L/min',
#  "forze_dell'ordine_presenti": False,
#  'immobilizzazioni': None,
#  'indirizzo_intervento': 'via Marconi 78, Firenze',
#  'indirizzo_residenza': 'via Leopardi 10',
#  'luogo_nascita': 'Firenze',
#  'mezzo_trasporto': 'ambulanza',
#  'monitoraggio_continuo': 'monitoraggio costante durante trasporto',
#  'nome_chiamante': 'Marco Bianchi',
#  'nome_soccorritore_1': 'Giulia Conti',
#  'nome_soccorritore_2': 'Davide Russo',
#  'nome_soccorritore_3': 'Federica Martini',
#  'note_intervento': 'Paziente con sospetta reazione allergica grave. '
#                     'Somministrata adrenalina IM e ossigenoterapia. '
#                     'Monitoraggio continuo. Trasporto in codice giallo al '
#                     'Pronto Soccorso.',
#  'numero_civico': '78',
#  'numero_intervento': 'PR150',
#  'ora_arrivo_ps': '10:00',
#  'ora_arrivo_sul_posto': '09:30',
#  'ora_chiamata': '09:20',
#  'ora_partenza_ambulanza': '09:23',
#  'ora_partenza_dal_posto': '09:45',
#  'ora_rientro_sede': '10:40',
#  'ospedale_destinazione': 'Ospedale Careggi, Firenze',
#  'ossigenoterapia': True,
#  'parametri_vitali': [{'AVPU': 'vigile e orientata',
#                        'ECG': 'tachicardia sinusale',
#                        'frequenza_cardiaca': '110 bpm',
#                        'frequenza_respiratoria': '32 atti/min',
#                        'glicemia': '90 mg/dL',
#                        'pressione_arteriosa': '120/75',
#                        'pupille_PEARL': 'normali, reagenti',
#                        'saturazione_ossigeno': '92%',
#                        'temperatura': '36.9°C',
#                        'tempo_rilevazione': '09:32'}],
#  'patologie_pregresse': None,
#  'paziente_consegnato_ps': True,
#  'paziente_rifiuto_trasporto': False,
#  'posizionamento_paziente': 'semi-seduta',
#  'problemi_riscontrati': 'nessuno',
#  'provincia': 'FI',
#  'provincia_nascita': 'FI',
#  'provincia_residenza': 'FI',
#  'relazione_con_paziente': 'fratello',
#  'reparto_destinazione': 'Pronto Soccorso',
#  'residenza': 'via Leopardi 10, Firenze',
#  'ruolo_soccorritore_1': 'infermiere',
#  'ruolo_soccorritore_2': 'autista soccorritore',
#  'ruolo_soccorritore_3': 'capo equipaggio',
#  'sesso': 'femminile',
#  'sintomi': ['gonfiore al viso',
#              'difficoltà respiratoria',
#              'orticaria diffusa',
#              'tachicardia'],
#  'soluzione_endovenosa': 'soluzione fisiologica',
#  'stato_coscienza': 'agitata ma cosciente',
#  'telefono_chiamante': '055-1234567',
#  'tipo_mezzo': 'ambulanza',
#  'via': 'via Marconi'}
# {'_id': ObjectId('684ed98b7a26fd46f566f376'),
#  'accesso_venoso': None,
#  'allergie': '',
#  'cap': '',
#  'citta': 'Parma',
#  'citta_residenza': 'Parma',
#  'codice_fiscale': '',
#  'codice_rientro': 'D5',
#  'codice_uscita': 'D4',
#  'cognome_chiamante': '',
#  'cognome_nome_paziente': 'Rossi Mario',
#  'condizioni_consegna': '',
#  'data': '',
#  'data_nascita': '12 marzo 1959',
#  'decesso_sul_posto': False,
#  'dolore_localizzato': None,
#  'eta': '',
#  'farmaci_assunti': '',
#  'farmaci_somministrati': [],
#  'firma_responsabile': '',
#  'flusso_ossigeno': '',
#  "forze_dell'ordine_presenti": True,
#  'immobilizzazioni': '',
#  'indirizzo_intervento': 'via Roma 24, Parma',
#  'indirizzo_residenza': 'via Venezia 3',
#  'luogo_nascita': '',
#  'mezzo_trasporto': 'ambulanza',
#  'monitoraggio_continuo': True,
#  'nome_chiamante': '',
#  'nome_soccorritore_1': None,
#  'nome_soccorritore_2': None,
#  'nome_soccorritore_3': None,
#  'note_intervento': '',
#  'numero_civico': '24',
#  'numero_intervento': 'PR123',
#  'ora_arrivo_ps': None,
#  'ora_arrivo_sul_posto': None,
#  'ora_chiamata': '09:41',
#  'ora_partenza_ambulanza': None,
#  'ora_partenza_dal_posto': None,
#  'ora_rientro_sede': None,
#  'ospedale_destinazione': 'Ospedale Maggiore di Parma',
#  'ossigenoterapia': 'iniziata in maschera',
#  'parametri_vitali': [{'AVPU': 'risponde solo a stimoli verbali',
#                        'ECG': '',
#                        'frequenza_cardiaca': '<60 bpm',
#                        'frequenza_respiratoria': '12 atti al minuto',
#                        'glicemia': '',
#                        'pressione_arteriosa': '',
#                        'pupille_PEARL': 'reagenti e simmetriche',
#                        'saturazione_ossigeno': '',
#                        'temperatura': '',
#                        'tempo_rilevazione': ''}],
#  'patologie_pregresse': '',
#  'paziente_consegnato_ps': True,
#  'paziente_rifiuto_trasporto': False,
#  'posizionamento_paziente': 'capo e tronco sollevati',
#  'problemi_riscontrati': '',
#  'provincia': None,
#  'provincia_nascita': '',
#  'provincia_residenza': None,
#  'relazione_con_paziente': 'parente',
#  'reparto_destinazione': '',
#  'residenza': 'via Venezia 3, Parma',
#  'ruolo_soccorritore_1': None,
#  'ruolo_soccorritore_2': None,
#  'ruolo_soccorritore_3': None,
#  'sesso': None,
#  'sintomi': ['vie aeree parzialmente ostruite da schiuma e vomito',
#              'bradipnea',
#              'respirazione rumorosa con russamento',
#              'polso debole sotto i 60 bpm',
#              'cianosi periferica',
#              'stato confusionale',
#              'emiparesi destra con deviazione della rima orale',
#              'difficoltà a parlare',
#              'impossibilità a deambulare'],
#  'soluzione_endovenosa': '',
#  'stato_coscienza': 'risponde solo a stimoli verbali',
#  'telefono_chiamante': '0521-000000',
#  'tipo_mezzo': 'ambulanza',
#  'via': 'Roma'}
# {'_id': ObjectId('684ed98b7a26fd46f566f377'),
#  'accesso_venoso': False,
#  'allergie': 'nessuna nota',
#  'cap': '43036',
#  'citta': 'Fidenza',
#  'citta_residenza': 'Fidenza',
#  'codice_fiscale': 'RCCSFN73C12G337T',
#  'codice_rientro': 'D1',
#  'codice_uscita': 'D1',
#  'cognome_chiamante': '',
#  'cognome_nome_paziente': 'Ricci Stefano',
#  'condizioni_consegna': 'vigile, collaborante, con dolore moderato',
#  'data': '2025-06-15',
#  'data_nascita': '1973-03-12',
#  'decesso_sul_posto': False,
#  'dolore_localizzato': 'caviglia destra',
#  'eta': '52 anni',
#  'farmaci_assunti': 'nessuno',
#  'farmaci_somministrati': [],
#  'firma_responsabile': 'G. Riva',
#  'flusso_ossigeno': '',
#  "forze_dell'ordine_presenti": False,
#  'immobilizzazioni': 'stecca caviglia, ghiaccio istantaneo',
#  'indirizzo_intervento': 'via Bellini 8, Fidenza',
#  'indirizzo_residenza': 'via Rossini 3',
#  'luogo_nascita': 'Parma',
#  'mezzo_trasporto': 'ambulanza',
#  'monitoraggio_continuo': 'dolore stabile, condizioni generali buone',
#  'nome_chiamante': 'passante',
#  'nome_soccorritore_1': 'Luca Neri',
#  'nome_soccorritore_2': 'Giulia Riva',
#  'nome_soccorritore_3': 'Carlo Bianchi',
#  'note_intervento': 'Il paziente è stato trovato seduto sul marciapiede, '
#                     'riferiva di essere scivolato. Ha camminato pochi metri ma '
#                     'lamentava dolore crescente alla caviglia destra. Dopo '
#                     'valutazione e immobilizzazione, è stato accompagnato in '
#                     'PS per accertamenti. Paziente stabile e tranquillo.',
#  'numero_civico': '8',
#  'numero_intervento': 'PR127',
#  'ora_arrivo_ps': '10:49',
#  'ora_arrivo_sul_posto': '10:24',
#  'ora_chiamata': '10:15',
#  'ora_partenza_ambulanza': '10:18',
#  'ora_partenza_dal_posto': '10:37',
#  'ora_rientro_sede': '11:10',
#  'ospedale_destinazione': 'Ospedale di Vaio',
#  'ossigenoterapia': False,
#  'parametri_vitali': [{'AVPU': 'vigile',
#                        'ECG': 'non eseguito',
#                        'frequenza_cardiaca': '84 bpm',
#                        'frequenza_respiratoria': '16 atti/min',
#                        'glicemia': '104 mg/dL',
#                        'pressione_arteriosa': '132/78',
#                        'pupille_PEARL': 'presenti, isocoriche, reagenti',
#                        'saturazione_ossigeno': '97%',
#                        'temperatura': '36.4°C',
#                        'tempo_rilevazione': '10:26'}],
#  'patologie_pregresse': 'nessuna di rilievo',
#  'paziente_consegnato_ps': True,
#  'paziente_rifiuto_trasporto': False,
#  'posizionamento_paziente': 'seduto',
#  'problemi_riscontrati': 'nessuno',
#  'provincia': 'PR',
#  'provincia_nascita': 'PR',
#  'provincia_residenza': 'PR',
#  'relazione_con_paziente': 'nessuna',
#  'reparto_destinazione': 'Pronto Soccorso',
#  'residenza': 'via Rossini 3, Fidenza',
#  'ruolo_soccorritore_1': 'autista soccorritore',
#  'ruolo_soccorritore_2': 'capo equipaggio',
#  'ruolo_soccorritore_3': 'soccorritore',
#  'sesso': 'maschile',
#  'sintomi': ['dolore caviglia destra'],
#  'soluzione_endovenosa': '',
#  'stato_coscienza': 'vigile e orientato',
#  'telefono_chiamante': '0524-556677',
#  'tipo_mezzo': 'ambulanza',
#  'via': 'via Bellini'}
# {'_id': ObjectId('684ed98b7a26fd46f566f378'),
#  'accesso_venoso': None,
#  'allergie': 'nessuna nota',
#  'cap': '29121',
#  'citta': 'Piacenza',
#  'citta_residenza': 'Piacenza',
#  'codice_fiscale': 'RSSMRA47S09G337A',
#  'codice_rientro': 'D2',
#  'codice_uscita': 'D2',
#  'cognome_chiamante': 'Rossi',
#  'cognome_nome_paziente': 'Rossi Mario',
#  'condizioni_consegna': 'vigile, affaticato ma stabile',
#  'data': '2025-06-15',
#  'data_nascita': '1947-11-09',
#  'decesso_sul_posto': False,
#  'dolore_localizzato': '',
#  'eta': '78 anni',
#  'farmaci_assunti': 'bronchodilatatori, antiipertensivi',
#  'farmaci_somministrati': [],
#  'firma_responsabile': 'L. Neri',
#  'flusso_ossigeno': '6 l/min con maschera Venturi',
#  "forze_dell'ordine_presenti": False,
#  'immobilizzazioni': None,
#  'indirizzo_intervento': 'via Leopardi 22, Piacenza',
#  'indirizzo_residenza': 'via Verdi 14',
#  'luogo_nascita': 'Piacenza',
#  'mezzo_trasporto': 'ambulanza',
#  'monitoraggio_continuo': 'monitoraggio parametri vitali e saturazione '
#                           'ossigeno',
#  'nome_chiamante': 'figlia',
#  'nome_soccorritore_1': 'Marco Bianchi',
#  'nome_soccorritore_2': 'Anna Verdi',
#  'nome_soccorritore_3': 'Luca Neri',
#  'note_intervento': 'Paziente con storia di BPCO in riacutizzazione. '
#                     'Ossigenoterapia con maschera Venturi iniziata, buona '
#                     'risposta. Monitoraggio continuo durante il trasporto. '
#                     'Paziente affidato al personale PS stabile ma da valutare '
#                     'per terapia e monitoraggio.',
#  'numero_civico': '22',
#  'numero_intervento': 'PR130',
#  'ora_arrivo_ps': '15:05',
#  'ora_arrivo_sul_posto': '14:33',
#  'ora_chiamata': '14:22',
#  'ora_partenza_ambulanza': '14:25',
#  'ora_partenza_dal_posto': '14:50',
#  'ora_rientro_sede': '15:30',
#  'ospedale_destinazione': 'Ospedale Guglielmo da Saliceto, Piacenza',
#  'ossigenoterapia': True,
#  'parametri_vitali': [{'AVPU': 'vigile',
#                        'ECG': 'non eseguito',
#                        'frequenza_cardiaca': '110 bpm',
#                        'frequenza_respiratoria': '28 atti/min',
#                        'glicemia': '110 mg/dL',
#                        'pressione_arteriosa': '145/85',
#                        'pupille_PEARL': 'isocoriche, reagenti',
#                        'saturazione_ossigeno': '88%',
#                        'temperatura': '36.7°C',
#                        'tempo_rilevazione': '14:35'},
#                       {'AVPU': 'vigile',
#                        'ECG': 'non eseguito',
#                        'frequenza_cardiaca': '102 bpm',
#                        'frequenza_respiratoria': '22 atti/min',
#                        'glicemia': '108 mg/dL',
#                        'pressione_arteriosa': '140/80',
#                        'pupille_PEARL': 'isocoriche, reagenti',
#                        'saturazione_ossigeno': '94%',
#                        'temperatura': '36.7°C',
#                        'tempo_rilevazione': '14:45'}],
#  'patologie_pregresse': 'BPCO, ipertensione',
#  'paziente_consegnato_ps': True,
#  'paziente_rifiuto_trasporto': False,
#  'posizionamento_paziente': 'semiseduto',
#  'problemi_riscontrati': 'nessuno',
#  'provincia': 'PC',
#  'provincia_nascita': 'PC',
#  'provincia_residenza': 'PC',
#  'relazione_con_paziente': 'figlia',
#  'reparto_destinazione': 'Pronto Soccorso',
#  'residenza': 'via Verdi 14, Piacenza',
#  'ruolo_soccorritore_1': 'autista soccorritore',
#  'ruolo_soccorritore_2': 'infermiere',
#  'ruolo_soccorritore_3': 'capo equipaggio',
#  'sesso': 'maschile',
#  'sintomi': ['difficoltà respiratoria', 'tosse secca', 'affaticamento'],
#  'soluzione_endovenosa': None,
#  'stato_coscienza': 'vigile ma confuso',
#  'telefono_chiamante': '0523-123456',
#  'tipo_mezzo': 'ambulanza',
#  'via': 'via Leopardi'}
# {'_id': ObjectId('685422b71427924aa183718a'),
#  'accesso_venoso': None,
#  'allergie': 'nessuna nota',
#  'cap': '40121',
#  'citta': 'Bologna',
#  'citta_residenza': 'Bologna',
#  'codice_fiscale': 'BNCLRA96C54A944P',
#  'codice_rientro': 'D3',
#  'codice_uscita': 'D3',
#  'cognome_chiamante': 'Bianchi',
#  'cognome_nome_paziente': 'Bianchi Laura',
#  'condizioni_consegna': 'vigile, collaborante, stabile',
#  'data': '2025-06-15',
#  'data_nascita': '1996-03-14',
#  'decesso_sul_posto': False,
#  'dolore_localizzato': 'polso sinistro',
#  'eta': '29 anni',
#  'farmaci_assunti': 'nessuno',
#  'farmaci_somministrati': [],
#  'firma_responsabile': 'M. Galli',
#  'flusso_ossigeno': None,
#  "forze_dell'ordine_presenti": False,
#  'immobilizzazioni': 'steccatura polso sinistro',
#  'indirizzo_intervento': 'via Manzoni 5, Bologna',
#  'indirizzo_residenza': 'via Verdi 12',
#  'luogo_nascita': 'Bologna',
#  'mezzo_trasporto': 'ambulanza',
#  'monitoraggio_continuo': 'monitoraggio parametri vitali durante trasporto',
#  'nome_chiamante': 'Marco Bianchi',
#  'nome_soccorritore_1': 'Giulia Rossi',
#  'nome_soccorritore_2': 'Luca Ferri',
#  'nome_soccorritore_3': 'Marco Galli',
#  'note_intervento': 'Paziente cosciente con trauma polso sinistro da caduta. '
#                     'Steccatura effettuata, medicati tagli al volto. '
#                     'Monitoraggio stabile durante trasporto. Paziente affidata '
#                     'al PS per approfondimenti diagnostici.',
#  'numero_civico': '5',
#  'numero_intervento': 'PR135',
#  'ora_arrivo_ps': '10:25',
#  'ora_arrivo_sul_posto': '09:55',
#  'ora_chiamata': '09:45',
#  'ora_partenza_ambulanza': '09:48',
#  'ora_partenza_dal_posto': '10:10',
#  'ora_rientro_sede': '10:50',
#  'ospedale_destinazione': 'Ospedale Maggiore, Bologna',
#  'ossigenoterapia': False,
#  'parametri_vitali': [{'AVPU': 'vigile',
#                        'ECG': 'non eseguito',
#                        'frequenza_cardiaca': '90 bpm',
#                        'frequenza_respiratoria': '18 atti/min',
#                        'glicemia': '95 mg/dL',
#                        'pressione_arteriosa': '120/75',
#                        'pupille_PEARL': 'isocoriche, reagenti',
#                        'saturazione_ossigeno': '98%',
#                        'temperatura': '36.5°C',
#                        'tempo_rilevazione': '09:57'}],
#  'patologie_pregresse': 'nessuna',
#  'paziente_consegnato_ps': True,
#  'paziente_rifiuto_trasporto': False,
#  'posizionamento_paziente': 'seduta',
#  'problemi_riscontrati': 'nessuno',
#  'provincia': 'BO',
#  'provincia_nascita': 'BO',
#  'provincia_residenza': 'BO',
#  'relazione_con_paziente': 'fratello',
#  'reparto_destinazione': 'Pronto Soccorso',
#  'residenza': 'via Verdi 12, Bologna',
#  'ruolo_soccorritore_1': 'infermiere',
#  'ruolo_soccorritore_2': 'autista soccorritore',
#  'ruolo_soccorritore_3': 'capo equipaggio',
#  'sesso': 'femminile',
#  'sintomi': ['dolore acuto al polso sinistro',
#              'abrasioni al volto',
#              'agitazione'],
#  'soluzione_endovenosa': None,
#  'stato_coscienza': 'vigile e orientata',
#  'telefono_chiamante': '051-1234567',
#  'tipo_mezzo': 'ambulanza',
#  'via': 'via Manzoni'}
# {'_id': ObjectId('685422b71427924aa183718b'),
#  'accesso_venoso': 'sì',
#  'allergie': 'non note',
#  'cap': '50137',
#  'citta': 'Firenze',
#  'citta_residenza': 'Firenze',
#  'codice_fiscale': 'GNTMRA36B51D403S',
#  'codice_rientro': 'Nero',
#  'codice_uscita': 'Rosso',
#  'cognome_chiamante': 'Mancini',
#  'cognome_nome_paziente': 'Gentili Maria',
#  'condizioni_consegna': '',
#  'data': '2025-06-18',
#  'data_nascita': '1936-02-11',
#  'decesso_sul_posto': True,
#  'dolore_localizzato': '',
#  'eta': '89',
#  'farmaci_assunti': 'insulina, furosemide, amlodipina',
#  'farmaci_somministrati': ['adrenalina 1mg (x3)'],
#  'firma_responsabile': 'Infermiere Edoardo Nesi',
#  'flusso_ossigeno': '15 L/min',
#  "forze_dell'ordine_presenti": True,
#  'immobilizzazioni': '',
#  'indirizzo_intervento': 'Via del Poggio 3, Firenze FI, 50137',
#  'indirizzo_residenza': 'Via del Poggio 3',
#  'luogo_nascita': 'Empoli',
#  'mezzo_trasporto': '',
#  'monitoraggio_continuo': 'sì',
#  'nome_chiamante': 'Giorgio',
#  'nome_soccorritore_1': 'Giulia Bianchi',
#  'nome_soccorritore_2': 'Edoardo Nesi',
#  'nome_soccorritore_3': 'Laura Mancini',
#  'note_intervento': 'Intervento presso domicilio per paziente anziana trovata '
#                     "incosciente dal vicino. All'arrivo, parametri assenti. "
#                     'RCP avanzata per circa 35 minuti, somministrati farmaci '
#                     'secondo protocollo. Decesso confermato alle ore 11:00. '
#                     'Carabinieri presenti, informato medico curante.',
#  'numero_civico': '3',
#  'numero_intervento': 'CR20250618-014',
#  'ora_arrivo_ps': '',
#  'ora_arrivo_sul_posto': '10:24',
#  'ora_chiamata': '10:15',
#  'ora_partenza_ambulanza': '10:17',
#  'ora_partenza_dal_posto': '11:10',
#  'ora_rientro_sede': '11:42',
#  'ospedale_destinazione': '',
#  'ossigenoterapia': 'sì',
#  'parametri_vitali': [{'AVPU': 'U',
#                        'ECG': 'linea piatta',
#                        'frequenza_cardiaca': '0',
#                        'frequenza_respiratoria': '0',
#                        'glicemia': '98 mg/dL',
#                        'pressione_arteriosa': '0',
#                        'pupille_PEARL': 'fisse e dilatate',
#                        'saturazione_ossigeno': '0',
#                        'temperatura': '33.9 °C',
#                        'tempo_rilevazione': '10:25'}],
#  'patologie_pregresse': 'scompenso cardiaco, diabete tipo II',
#  'paziente_consegnato_ps': False,
#  'paziente_rifiuto_trasporto': False,
#  'posizionamento_paziente': 'supina su letto',
#  'problemi_riscontrati': 'difficoltà di accesso al piano superiore senza '
#                          'ascensore',
#  'provincia': 'FI',
#  'provincia_nascita': 'FI',
#  'provincia_residenza': 'FI',
#  'relazione_con_paziente': 'vicino di casa',
#  'reparto_destinazione': '',
#  'residenza': 'Via del Poggio 3',
#  'ruolo_soccorritore_1': 'soccorritore',
#  'ruolo_soccorritore_2': 'infermiere',
#  'ruolo_soccorritore_3': 'autista soccorritore',
#  'sesso': 'F',
#  'sintomi': ['assenza di respiro', 'freddo corporeo', 'assenza di battito'],
#  'soluzione_endovenosa': 'ringer lattato',
#  'stato_coscienza': 'incosciente',
#  'telefono_chiamante': '055330997',
#  'tipo_mezzo': 'MSA',
#  'via': 'Via del Poggio'}
# {'_id': ObjectId('685422b71427924aa183718c'),
#  'accesso_venoso': None,
#  'allergie': None,
#  'cap': '',
#  'citta': 'Parma',
#  'citta_residenza': None,
#  'codice_fiscale': None,
#  'codice_rientro': 'D4',
#  'codice_uscita': 'D2',
#  'cognome_chiamante': '',
#  'cognome_nome_paziente': None,
#  'condizioni_consegna': '',
#  'data': '',
#  'data_nascita': None,
#  'decesso_sul_posto': False,
#  'dolore_localizzato': 'addome',
#  'eta': 'circa 35 anni',
#  'farmaci_assunti': None,
#  'farmaci_somministrati': [],
#  'firma_responsabile': '',
#  'flusso_ossigeno': None,
#  "forze_dell'ordine_presenti": None,
#  'immobilizzazioni': None,
#  'indirizzo_intervento': 'via Verdi 10, Parma',
#  'indirizzo_residenza': None,
#  'luogo_nascita': '',
#  'mezzo_trasporto': 'ambulanza',
#  'monitoraggio_continuo': '',
#  'nome_chiamante': '',
#  'nome_soccorritore_1': '',
#  'nome_soccorritore_2': '',
#  'nome_soccorritore_3': '',
#  'note_intervento': 'Posizionato in sicurezza con mantenimento della posizione '
#                     'antalgica, assistito durante i conati e monitorato per la '
#                     'pervietà delle vie aeree. Iniziato monitoraggio dei '
#                     'parametri vitali. Raccolta anamnesi sul posto, richiesto '
#                     'trasporto in codice giallo verso Pronto Soccorso per '
#                     'sospetta intossicazione alimentare.',
#  'numero_civico': '10',
#  'numero_intervento': 'PR125',
#  'ora_arrivo_ps': '17:30',
#  'ora_arrivo_sul_posto': '17:20',
#  'ora_chiamata': '17:11',
#  'ora_partenza_ambulanza': '17:15',
#  'ora_partenza_dal_posto': '17:25',
#  'ora_rientro_sede': '17:38',
#  'ospedale_destinazione': None,
#  'ossigenoterapia': None,
#  'parametri_vitali': [{'AVPU': 'vigile e orientato',
#                        'ECG': '',
#                        'frequenza_cardiaca': '<100 bpm',
#                        'frequenza_respiratoria': '>25 atti al minuto',
#                        'glicemia': None,
#                        'pressione_arteriosa': '',
#                        'pupille_PEARL': '',
#                        'saturazione_ossigeno': None,
#                        'temperatura': None,
#                        'tempo_rilevazione': ''}],
#  'patologie_pregresse': None,
#  'paziente_consegnato_ps': True,
#  'paziente_rifiuto_trasporto': False,
#  'posizionamento_paziente': 'posizione antalgica',
#  'problemi_riscontrati': '',
#  'provincia': '',
#  'provincia_nascita': '',
#  'provincia_residenza': None,
#  'relazione_con_paziente': '',
#  'reparto_destinazione': 'Pronto Soccorso',
#  'residenza': None,
#  'ruolo_soccorritore_1': '',
#  'ruolo_soccorritore_2': '',
#  'ruolo_soccorritore_3': '',
#  'sesso': 'maschile',
#  'sintomi': ['forti dolori addominali',
#              'nausea intensa',
#              'ripetuti episodi di vomito'],
#  'soluzione_endovenosa': None,
#  'stato_coscienza': 'vigile e orientato',
#  'telefono_chiamante': '0521‑000002',
#  'tipo_mezzo': 'ambulanza',
#  'via': 'via Verdi'}
# {'_id': ObjectId('685422b71427924aa183718d'),
#  'accesso_venoso': 'no',
#  'allergie': 'nessuna nota',
#  'cap': '00172',
#  'citta': 'Roma',
#  'citta_residenza': 'Roma',
#  'codice_fiscale': 'BNCLSN09C12H501X',
#  'codice_rientro': 'VERDE',
#  'codice_uscita': 'GIALLO',
#  'cognome_chiamante': 'Bianchi',
#  'cognome_nome_paziente': 'Bianchi Alessandro',
#  'condizioni_consegna': 'stabili',
#  'data': '2025-06-18',
#  'data_nascita': '2009-03-12',
#  'decesso_sul_posto': False,
#  'dolore_localizzato': 'torace sinistro',
#  'eta': '16',
#  'farmaci_assunti': 'salbutamolo spray',
#  'farmaci_somministrati': [],
#  'firma_responsabile': 'firma digitale acquisita',
#  'flusso_ossigeno': '4 L/min',
#  "forze_dell'ordine_presenti": None,
#  'immobilizzazioni': 'no',
#  'indirizzo_intervento': 'Via delle Ginestre 14',
#  'indirizzo_residenza': 'Via delle Ortensie 10',
#  'luogo_nascita': 'Roma',
#  'mezzo_trasporto': 'ambulanza BLS',
#  'monitoraggio_continuo': 'sì',
#  'nome_chiamante': 'Marco',
#  'nome_soccorritore_1': 'Lucia Ferri',
#  'nome_soccorritore_2': 'Matteo Ricci',
#  'nome_soccorritore_3': 'Elena Neri',
#  'note_intervento': 'paziente collaborante, famiglia informata',
#  'numero_civico': '14',
#  'numero_intervento': '1458',
#  'ora_arrivo_ps': '14:44',
#  'ora_arrivo_sul_posto': '14:27',
#  'ora_chiamata': '14:12',
#  'ora_partenza_ambulanza': '14:15',
#  'ora_partenza_dal_posto': '14:34',
#  'ora_rientro_sede': '14:56',
#  'ospedale_destinazione': 'Ospedale Sandro Pertini',
#  'ossigenoterapia': 'sì',
#  'parametri_vitali': [{'AVPU': 'A',
#                        'ECG': 'ritmo sinusale',
#                        'frequenza_cardiaca': '108',
#                        'frequenza_respiratoria': '24',
#                        'glicemia': '92',
#                        'pressione_arteriosa': '125/80',
#                        'pupille_PEARL': 'sì',
#                        'saturazione_ossigeno': '94',
#                        'temperatura': '36.9',
#                        'tempo_rilevazione': '14:28'}],
#  'patologie_pregresse': 'asma bronchiale',
#  'paziente_consegnato_ps': True,
#  'paziente_rifiuto_trasporto': False,
#  'posizionamento_paziente': 'decubito supino',
#  'problemi_riscontrati': '',
#  'provincia': 'RM',
#  'provincia_nascita': 'RM',
#  'provincia_residenza': 'RM',
#  'relazione_con_paziente': 'Padre',
#  'reparto_destinazione': "Medicina d'Urgenza",
#  'residenza': 'Via delle Ortensie 10',
#  'ruolo_soccorritore_1': 'autista soccorritore',
#  'ruolo_soccorritore_2': 'caposquadra',
#  'ruolo_soccorritore_3': 'soccorritrice',
#  'sesso': 'M',
#  'sintomi': ['dolore toracico', 'dispnea'],
#  'soluzione_endovenosa': '',
#  'stato_coscienza': 'vigile',
#  'telefono_chiamante': '3391122334',
#  'tipo_mezzo': 'BLS-CR-02',
#  'via': 'Via delle Ginestre'}
# {'_id': ObjectId('685422b71427924aa183718e'),
#  'accesso_venoso': 'no',
#  'allergie': 'nessuna nota',
#  'cap': '50053',
#  'citta': 'Empoli',
#  'citta_residenza': 'Empoli',
#  'codice_fiscale': 'RSSMRC50S23E483B',
#  'codice_rientro': 'Verde',
#  'codice_uscita': 'Giallo',
#  'cognome_chiamante': 'Rossi',
#  'cognome_nome_paziente': 'Rossi Marco',
#  'condizioni_consegna': 'vigile, dolore controllato, trasportato in sicurezza',
#  'data': '2025-06-18',
#  'data_nascita': '1950-11-23',
#  'decesso_sul_posto': False,
#  'dolore_localizzato': 'anca destra',
#  'eta': '74',
#  'farmaci_assunti': 'amlodipina, paracetamolo',
#  'farmaci_somministrati': ['paracetamolo'],
#  'firma_responsabile': 'Alessandro Neri',
#  'flusso_ossigeno': '',
#  "forze_dell'ordine_presenti": None,
#  'immobilizzazioni': 'steccatura arto inferiore destro',
#  'indirizzo_intervento': 'Via del Molino 7, Empoli FI, 50053',
#  'indirizzo_residenza': 'Via dei Mille 18',
#  'luogo_nascita': 'Empoli',
#  'mezzo_trasporto': 'ambulanza MSA',
#  'monitoraggio_continuo': 'no',
#  'nome_chiamante': 'Lucia',
#  'nome_soccorritore_1': 'Elena Gori',
#  'nome_soccorritore_2': 'Alessandro Neri',
#  'nome_soccorritore_3': 'Luca Vannucci',
#  'note_intervento': 'Caduta accidentale in bagno, sospetta frattura anca '
#                     'destra. Immobilizzato e trasportato con cautela.',
#  'numero_civico': '7',
#  'numero_intervento': 'CR20250618-024',
#  'ora_arrivo_ps': '15:10',
#  'ora_arrivo_sul_posto': '14:54',
#  'ora_chiamata': '14:46',
#  'ora_partenza_ambulanza': '14:48',
#  'ora_partenza_dal_posto': '15:02',
#  'ora_rientro_sede': '15:38',
#  'ospedale_destinazione': 'Ospedale San Giuseppe di Empoli',
#  'ossigenoterapia': 'no',
#  'parametri_vitali': [{'AVPU': 'A',
#                        'ECG': 'regolare sinusale',
#                        'frequenza_cardiaca': '76 bpm',
#                        'frequenza_respiratoria': '18 atti/min',
#                        'glicemia': '105 mg/dL',
#                        'pressione_arteriosa': '135/80',
#                        'pupille_PEARL': 'normali',
#                        'saturazione_ossigeno': '96%',
#                        'temperatura': '36.6 °C',
#                        'tempo_rilevazione': '14:56'}],
#  'patologie_pregresse': 'artrosi, ipertensione',
#  'paziente_consegnato_ps': True,
#  'paziente_rifiuto_trasporto': False,
#  'posizionamento_paziente': 'seduto semi-sdraiato',
#  'problemi_riscontrati': 'assenza ascensore, trasporto effettuato con sedia '
#                          'portantina',
#  'provincia': 'FI',
#  'provincia_nascita': 'FI',
#  'provincia_residenza': 'FI',
#  'relazione_con_paziente': 'moglie',
#  'reparto_destinazione': 'Ortopedia',
#  'residenza': 'Via dei Mille 18',
#  'ruolo_soccorritore_1': 'autista soccorritore',
#  'ruolo_soccorritore_2': 'capo equipaggio',
#  'ruolo_soccorritore_3': 'soccorritore',
#  'sesso': 'M',
#  'sintomi': ["dolore all'anca destra", 'difficoltà a deambulare'],
#  'soluzione_endovenosa': '',
#  'stato_coscienza': 'vigile',
#  'telefono_chiamante': '0571798765',
#  'tipo_mezzo': 'MSA',
#  'via': 'Via del Molino'}
# {'_id': ObjectId('685422b71427924aa183718f'),
#  'accesso_venoso': True,
#  'allergie': 'allergica a penicillina',
#  'cap': '43036',
#  'citta': 'Fidenza',
#  'citta_residenza': 'Fidenza',
#  'codice_fiscale': 'FRRMRN47S48D548X',
#  'codice_rientro': 'D3',
#  'codice_uscita': 'D1',
#  'cognome_chiamante': 'Ferrari',
#  'cognome_nome_paziente': 'Ferrari Maria',
#  'condizioni_consegna': 'saturazione migliorata, paziente ancora confusa ma '
#                         'stabilizzata',
#  'data': '2025-06-15',
#  'data_nascita': '1947-11-08',
#  'decesso_sul_posto': False,
#  'dolore_localizzato': 'nessuno riferito',
#  'eta': '78 anni',
#  'farmaci_assunti': 'ramipril, broncodilatatori',
#  'farmaci_somministrati': [],
#  'firma_responsabile': 'F. Leoni',
#  'flusso_ossigeno': '6 L/min',
#  "forze_dell'ordine_presenti": False,
#  'immobilizzazioni': None,
#  'indirizzo_intervento': 'via Montale 22, Fidenza',
#  'indirizzo_residenza': 'via Verga 5',
#  'luogo_nascita': 'Fidenza',
#  'mezzo_trasporto': 'ambulanza',
#  'monitoraggio_continuo': 'parametri monitorati costantemente, miglioramento '
#                           'progressivo saturazione',
#  'nome_chiamante': 'Laura',
#  'nome_soccorritore_1': 'Sara Conti',
#  'nome_soccorritore_2': 'Francesco Leoni',
#  'nome_soccorritore_3': 'Martina Rossi',
#  'note_intervento': 'Paziente di 78 anni trovata all’interno della propria '
#                     'abitazione in stato confusionale, con segni di difficoltà '
#                     'respiratoria. La figlia ha riferito insorgenza improvvisa '
#                     'dei sintomi. Paziente collaborante ma disorientata. '
#                     'Saturazione iniziale 89%, avviata ossigenoterapia con '
#                     'miglioramento progressivo. Posizionato accesso venoso e '
#                     'infusa fisiologica in infusione lenta. Monitoraggio '
#                     'continuo durante il trasporto in codice rosso verso '
#                     'l’Ospedale di Fidenza. Consegnata in PS con condizioni in '
#                     'leggero miglioramento.',
#  'numero_civico': '22',
#  'numero_intervento': 'PR126',
#  'ora_arrivo_ps': '09:24',
#  'ora_arrivo_sul_posto': '08:53',
#  'ora_chiamata': '08:42',
#  'ora_partenza_ambulanza': '08:45',
#  'ora_partenza_dal_posto': '09:08',
#  'ora_rientro_sede': '09:50',
#  'ospedale_destinazione': 'Ospedale di Fidenza',
#  'ossigenoterapia': True,
# ...
#  'accesso_venoso': 'posizionato su arto superiore dx',
#  'allergie': 'nessuna nota',
#  'cap': '50132',
#  'citta': 'Firenze',
#  'citta_residenza': 'Firenze',
#  'codice_fiscale': 'RSSMRC68S02G702T',
#  'codice_rientro': 'Verde',
#  'codice_uscita': 'Giallo',
#  'cognome_chiamante': 'Bianchi',
#  'cognome_nome_paziente': 'Rossi Marco',
#  'condizioni_consegna': 'cosciente, collaborante, sintomi lievemente attenuati',
#  'data': '2025-06-18',
#  'data_nascita': '1968-11-02',
#  'decesso_sul_posto': False,
#  'dolore_localizzato': 'petto sinistro',
#  'eta': '56',
#  'farmaci_assunti': 'Ramipril',
#  'farmaci_somministrati': ['aspirina 250mg OS'],
#  'firma_responsabile': 'Luca Fabbri',
#  'flusso_ossigeno': '2 L/min',
#  "forze_dell'ordine_presenti": None,
#  'immobilizzazioni': 'non necessarie',
#  'indirizzo_intervento': 'Via delle Magnolie 27, Firenze FI, 50132',
#  'indirizzo_residenza': 'Via Garibaldi 13',
#  'luogo_nascita': 'Pisa',
#  'mezzo_trasporto': 'ambulanza MSA',
#  'monitoraggio_continuo': 'sì',
#  'nome_chiamante': 'Lucia',
#  'nome_soccorritore_1': 'Giulia Neri',
#  'nome_soccorritore_2': 'Luca Fabbri',
#  'nome_soccorritore_3': 'Elisa Conti',
#  'note_intervento': 'Paziente trasportato in PS con monitoraggio continuo. '
#                     "Dolore toracico in fase di regressione all'arrivo.",
#  'numero_civico': '27',
#  'numero_intervento': 'CR20250618-045',
#  'ora_arrivo_ps': '14:56',
#  'ora_arrivo_sul_posto': '14:40',
#  'ora_chiamata': '14:32',
#  'ora_partenza_ambulanza': '14:34',
#  'ora_partenza_dal_posto': '14:47',
#  'ora_rientro_sede': '15:15',
#  'ospedale_destinazione': 'Ospedale Careggi, Firenze',
#  'ossigenoterapia': 'sì',
#  'parametri_vitali': [{'AVPU': 'A',
#                        'ECG': 'ritmo sinusale tachicardico',
#                        'frequenza_cardiaca': '102 bpm',
#                        'frequenza_respiratoria': '22 atti/min',
#                        'glicemia': '105 mg/dL',
#                        'pressione_arteriosa': '150/95',
#                        'pupille_PEARL': 'Sì',
#                        'saturazione_ossigeno': '96%',
#                        'temperatura': '36.7 °C',
#                        'tempo_rilevazione': '14:42'}],
#  'patologie_pregresse': 'ipertensione',
#  'paziente_consegnato_ps': True,
#  'paziente_rifiuto_trasporto': False,
#  'posizionamento_paziente': 'semi-seduto su barella',
#  'problemi_riscontrati': 'leggera difficoltà di parcheggio, gestita senza '
#                          'ritardi',
#  'provincia': 'FI',
#  'provincia_nascita': 'PI',
#  'provincia_residenza': 'FI',
#  'relazione_con_paziente': 'Moglie',
#  'reparto_destinazione': 'Pronto Soccorso',
#  'residenza': 'Via Garibaldi 13',
#  'ruolo_soccorritore_1': 'autista soccorritore',
#  'ruolo_soccorritore_2': 'capo equipaggio',
#  'ruolo_soccorritore_3': 'soccorritore',
#  'sesso': 'M',
#  'sintomi': ['dolore toracico', 'sudorazione', 'nausea'],
#  'soluzione_endovenosa': 'NaCl 0.9%',
#  'stato_coscienza': 'vigile',
#  'telefono_chiamante': '3381234567',
#  'tipo_mezzo': 'MSA',
#  'via': 'Via delle Magnolie'}
# {'_id': ObjectId('685422b71427924aa1837199'),
#  'accesso_venoso': 'sì',
#  'allergie': 'nessuna nota',
#  'cap': '52100',
#  'citta': 'Arezzo',
#  'citta_residenza': 'Arezzo',
#  'codice_fiscale': 'BNCCRL42C18A390Z',
#  'codice_rientro': 'Nero',
#  'codice_uscita': 'Rosso',
#  'cognome_chiamante': 'Bianchi',
#  'cognome_nome_paziente': 'Bianchi Carlo',
#  'condizioni_consegna': '',
#  'data': '2025-06-18',
#  'data_nascita': '1942-03-18',
#  'decesso_sul_posto': True,
#  'dolore_localizzato': '',
#  'eta': '83',
#  'farmaci_assunti': 'metformina, cardioaspirina',
#  'farmaci_somministrati': ['adrenalina 1mg (x3)', 'atropina'],
#  'firma_responsabile': 'Sara Benedetti',
#  'flusso_ossigeno': '15 L/min',
#  "forze_dell'ordine_presenti": True,
#  'immobilizzazioni': '',
#  'indirizzo_intervento': 'Via dei Cipressi 11, Arezzo AR, 52100',
#  'indirizzo_residenza': 'Via dei Cipressi 11',
#  'luogo_nascita': 'Arezzo',
#  'mezzo_trasporto': '',
#  'monitoraggio_continuo': 'sì',
#  'nome_chiamante': 'Giulia',
#  'nome_soccorritore_1': 'Marco Vitali',
#  'nome_soccorritore_2': 'Sara Benedetti',
#  'nome_soccorritore_3': 'Giovanni Parisi',
#  'note_intervento': 'All’arrivo sul posto il paziente risultava privo di segni '
#                     'vitali. Avviate manovre di rianimazione per 40 minuti, '
#                     'somministrati 3 boli di adrenalina, ma nessun ritorno di '
#                     'circolo. Forze dell’ordine presenti. Medico legale atteso '
#                     'per constatazione ufficiale del decesso.',
#  'numero_civico': '11',
#  'numero_intervento': 'CR20250618-005',
#  'ora_arrivo_ps': '',
#  'ora_arrivo_sul_posto': '06:20',
#  'ora_chiamata': '06:12',
#  'ora_partenza_ambulanza': '06:14',
#  'ora_partenza_dal_posto': '07:05',
#  'ora_rientro_sede': '07:35',
#  'ospedale_destinazione': '',
#  'ossigenoterapia': 'sì',
#  'parametri_vitali': [{'AVPU': 'U',
#                        'ECG': 'linea piatta',
#                        'frequenza_cardiaca': '0',
#                        'frequenza_respiratoria': '0',
#                        'glicemia': '98 mg/dL',
#                        'pressione_arteriosa': '0',
#                        'pupille_PEARL': 'fisse e dilatate',
#                        'saturazione_ossigeno': '0',
#                        'temperatura': '35.2 °C',
#                        'tempo_rilevazione': '06:21'}],
#  'patologie_pregresse': 'infarto pregresso, diabete mellito',
#  'paziente_consegnato_ps': False,
#  'paziente_rifiuto_trasporto': False,
#  'posizionamento_paziente': 'supino',
#  'problemi_riscontrati': 'nessuno',
#  'provincia': 'AR',
#  'provincia_nascita': 'AR',
#  'provincia_residenza': 'AR',
#  'relazione_con_paziente': 'figlia',
#  'reparto_destinazione': '',
#  'residenza': 'Via dei Cipressi 11',
#  'ruolo_soccorritore_1': 'autista soccorritore',
#  'ruolo_soccorritore_2': 'infermiere',
#  'ruolo_soccorritore_3': 'soccorritore',
#  'sesso': 'M',
#  'sintomi': ['assenza di respiro', 'assenza di battito', 'cianosi'],
#  'soluzione_endovenosa': 'ringer lattato',
#  'stato_coscienza': 'incosciente',
#  'telefono_chiamante': '0575301229',
#  'tipo_mezzo': 'MSA',
#  'via': 'Via dei Cipressi'}
# {'_id': ObjectId('685422b71427924aa183719a'),
#  'accesso_venoso': False,
#  'allergie': 'nessuna nota',
#  'cap': '43036',
#  'citta': 'Fidenza',
#  'citta_residenza': 'Fidenza',
#  'codice_fiscale': 'RCCSFN73C12G337T',
#  'codice_rientro': 'D1',
#  'codice_uscita': 'D1',
#  'cognome_chiamante': '',
#  'cognome_nome_paziente': 'Ricci Stefano',
#  'condizioni_consegna': 'vigile, collaborante, con dolore moderato',
#  'data': '2025-06-15',
#  'data_nascita': '1973-03-12',
#  'decesso_sul_posto': False,
#  'dolore_localizzato': 'caviglia destra',
#  'eta': '52 anni',
#  'farmaci_assunti': 'nessuno',
#  'farmaci_somministrati': [],
#  'firma_responsabile': 'G. Riva',
#  'flusso_ossigeno': '',
#  "forze_dell'ordine_presenti": False,
#  'immobilizzazioni': 'stecca caviglia, ghiaccio istantaneo',
#  'indirizzo_intervento': 'via Bellini 8, Fidenza',
#  'indirizzo_residenza': 'via Rossini 3',
#  'luogo_nascita': 'Parma',
#  'mezzo_trasporto': 'ambulanza',
#  'monitoraggio_continuo': 'dolore stabile, condizioni generali buone',
#  'nome_chiamante': 'passante',
#  'nome_soccorritore_1': 'Luca Neri',
#  'nome_soccorritore_2': 'Giulia Riva',
#  'nome_soccorritore_3': 'Carlo Bianchi',
#  'note_intervento': 'Il paziente è stato trovato seduto sul marciapiede, '
#                     'riferiva di essere scivolato. Ha camminato pochi metri ma '
#                     'lamentava dolore crescente alla caviglia destra. Dopo '
#                     'valutazione e immobilizzazione, è stato accompagnato in '
#                     'PS per accertamenti. Paziente stabile e tranquillo.',
#  'numero_civico': '8',
#  'numero_intervento': 'PR127',
#  'ora_arrivo_ps': '10:49',
#  'ora_arrivo_sul_posto': '10:24',
#  'ora_chiamata': '10:15',
#  'ora_partenza_ambulanza': '10:18',
#  'ora_partenza_dal_posto': '10:37',
#  'ora_rientro_sede': '11:10',
#  'ospedale_destinazione': 'Ospedale di Vaio',
#  'ossigenoterapia': False,
#  'parametri_vitali': [{'AVPU': 'vigile',
#                        'ECG': 'non eseguito',
#                        'frequenza_cardiaca': '84 bpm',
#                        'frequenza_respiratoria': '16 atti/min',
#                        'glicemia': '104 mg/dL',
#                        'pressione_arteriosa': '132/78',
#                        'pupille_PEARL': 'presenti, isocoriche, reagenti',
#                        'saturazione_ossigeno': '97%',
#                        'temperatura': '36.4°C',
#                        'tempo_rilevazione': '10:26'}],
#  'patologie_pregresse': 'nessuna di rilievo',
#  'paziente_consegnato_ps': True,
#  'paziente_rifiuto_trasporto': False,
#  'posizionamento_paziente': 'seduto',
#  'problemi_riscontrati': 'nessuno',
#  'provincia': 'PR',
#  'provincia_nascita': 'PR',
#  'provincia_residenza': 'PR',
#  'relazione_con_paziente': 'nessuna',
#  'reparto_destinazione': 'Pronto Soccorso',
#  'residenza': 'via Rossini 3, Fidenza',
#  'ruolo_soccorritore_1': 'autista soccorritore',
#  'ruolo_soccorritore_2': 'capo equipaggio',
#  'ruolo_soccorritore_3': 'soccorritore',
#  'sesso': 'maschile',
#  'sintomi': ['dolore caviglia destra'],
#  'soluzione_endovenosa': '',
#  'stato_coscienza': 'vigile e orientato',
#  'telefono_chiamante': '0524-556677',
#  'tipo_mezzo': 'ambulanza',
#  'via': 'via Bellini'}
# {'_id': ObjectId('685422b71427924aa183719b'),
#  'accesso_venoso': None,
#  'allergie': 'nessuna nota',
#  'cap': '29121',
#  'citta': 'Piacenza',
#  'citta_residenza': 'Piacenza',
#  'codice_fiscale': 'RSSMRA47S09G337A',
#  'codice_rientro': 'D2',
#  'codice_uscita': 'D2',
#  'cognome_chiamante': 'Rossi',
#  'cognome_nome_paziente': 'Rossi Mario',
#  'condizioni_consegna': 'vigile, affaticato ma stabile',
#  'data': '2025-06-15',
#  'data_nascita': '1947-11-09',
#  'decesso_sul_posto': False,
#  'dolore_localizzato': '',
#  'eta': '78 anni',
#  'farmaci_assunti': 'bronchodilatatori, antiipertensivi',
#  'farmaci_somministrati': [],
#  'firma_responsabile': 'L. Neri',
#  'flusso_ossigeno': '6 l/min con maschera Venturi',
#  "forze_dell'ordine_presenti": False,
#  'immobilizzazioni': None,
#  'indirizzo_intervento': 'via Leopardi 22, Piacenza',
#  'indirizzo_residenza': 'via Verdi 14',
#  'luogo_nascita': 'Piacenza',
#  'mezzo_trasporto': 'ambulanza',
#  'monitoraggio_continuo': 'monitoraggio parametri vitali e saturazione '
#                           'ossigeno',
#  'nome_chiamante': 'figlia',
#  'nome_soccorritore_1': 'Marco Bianchi',
#  'nome_soccorritore_2': 'Anna Verdi',
#  'nome_soccorritore_3': 'Luca Neri',
#  'note_intervento': 'Paziente con storia di BPCO in riacutizzazione. '
#                     'Ossigenoterapia con maschera Venturi iniziata, buona '
#                     'risposta. Monitoraggio continuo durante il trasporto. '
#                     'Paziente affidato al personale PS stabile ma da valutare '
#                     'per terapia e monitoraggio.',
#  'numero_civico': '22',
#  'numero_intervento': 'PR130',
#  'ora_arrivo_ps': '15:05',
#  'ora_arrivo_sul_posto': '14:33',
#  'ora_chiamata': '14:22',
#  'ora_partenza_ambulanza': '14:25',
#  'ora_partenza_dal_posto': '14:50',
#  'ora_rientro_sede': '15:30',
#  'ospedale_destinazione': 'Ospedale Guglielmo da Saliceto, Piacenza',
#  'ossigenoterapia': True,
#  'parametri_vitali': [{'AVPU': 'vigile',
#                        'ECG': 'non eseguito',
#                        'frequenza_cardiaca': '110 bpm',
#                        'frequenza_respiratoria': '28 atti/min',
#                        'glicemia': '110 mg/dL',
#                        'pressione_arteriosa': '145/85',
#                        'pupille_PEARL': 'isocoriche, reagenti',
#                        'saturazione_ossigeno': '88%',
#                        'temperatura': '36.7°C',
#                        'tempo_rilevazione': '14:35'},
#                       {'AVPU': 'vigile',
#                        'ECG': 'non eseguito',
#                        'frequenza_cardiaca': '102 bpm',
#                        'frequenza_respiratoria': '22 atti/min',
#                        'glicemia': '108 mg/dL',
#                        'pressione_arteriosa': '140/80',
#                        'pupille_PEARL': 'isocoriche, reagenti',
#                        'saturazione_ossigeno': '94%',
#                        'temperatura': '36.7°C',
#                        'tempo_rilevazione': '14:45'}],
#  'patologie_pregresse': 'BPCO, ipertensione',
#  'paziente_consegnato_ps': True,
#  'paziente_rifiuto_trasporto': False,
#  'posizionamento_paziente': 'semiseduto',
#  'problemi_riscontrati': 'nessuno',
#  'provincia': 'PC',
#  'provincia_nascita': 'PC',
#  'provincia_residenza': 'PC',
#  'relazione_con_paziente': 'figlia',
#  'reparto_destinazione': 'Pronto Soccorso',
#  'residenza': 'via Verdi 14, Piacenza',
#  'ruolo_soccorritore_1': 'autista soccorritore',
#  'ruolo_soccorritore_2': 'infermiere',
#  'ruolo_soccorritore_3': 'capo equipaggio',
#  'sesso': 'maschile',
#  'sintomi': ['difficoltà respiratoria', 'tosse secca', 'affaticamento'],
#  'soluzione_endovenosa': None,
#  'stato_coscienza': 'vigile ma confuso',
#  'telefono_chiamante': '0523-123456',
#  'tipo_mezzo': 'ambulanza',
#  'via': 'via Leopardi'}
# {'_id': ObjectId('685422b71427924aa183719c'),
#  'accesso_venoso': 'sì',
#  'allergie': 'non note',
#  'cap': '53100',
#  'citta': 'Siena',
#  'citta_residenza': 'Siena',
#  'codice_fiscale': 'RSSNDR71P21I726D',
#  'codice_rientro': 'Nero',
#  'codice_uscita': 'Rosso',
#  'cognome_chiamante': 'Ferrari',
#  'cognome_nome_paziente': 'Rossi Andrea',
#  'condizioni_consegna': '',
#  'data': '2025-06-18',
#  'data_nascita': '1971-09-21',
#  'decesso_sul_posto': True,
#  'dolore_localizzato': '',
#  'eta': '53',
#  'farmaci_assunti': 'ramipril',
#  'farmaci_somministrati': ['adrenalina 1mg (x4)', 'atropina', 'amiodarone'],
#  'firma_responsabile': 'Dott.ssa Marta Moretti',
#  'flusso_ossigeno': '12 L/min',
#  "forze_dell'ordine_presenti": True,
#  'immobilizzazioni': '',
#  'indirizzo_intervento': 'Parco Comunale, Viale dei Platani, Siena SI, 53100',
#  'indirizzo_residenza': 'Via delle Rose 2',
#  'luogo_nascita': 'Siena',
#  'mezzo_trasporto': '',
#  'monitoraggio_continuo': 'sì',
#  'nome_chiamante': 'Luca',
#  'nome_soccorritore_1': 'Lorenzo Neri',
#  'nome_soccorritore_2': 'Marta Moretti',
#  'nome_soccorritore_3': 'Chiara Rinaldi',
#  'note_intervento': 'All’arrivo sul posto, paziente in asistolia. Avviate '
#                     'immediatamente manovre di rianimazione cardio-polmonare. '
#                     'Defibrillazioni inefficaci. Somministrati 4 boli di '
#                     'adrenalina, atropina e amiodarone. Nessun ritorno del '
#                     'circolo spontaneo. Decesso constatato alle ore 18:25. '
#                     'Presente pattuglia dei Carabinieri. Medico legale '
#                     'allertato.',
#  'numero_civico': '',
#  'numero_intervento': 'CR20250618-011',
#  'ora_arrivo_ps': '',
#  'ora_arrivo_sul_posto': '17:55',
#  'ora_chiamata': '17:45',
#  'ora_partenza_ambulanza': '17:47',
#  'ora_partenza_dal_posto': '18:32',
#  'ora_rientro_sede': '19:00',
#  'ospedale_destinazione': '',
#  'ossigenoterapia': 'sì',
#  'parametri_vitali': [{'AVPU': 'U',
#                        'ECG': 'asistolia',
#                        'frequenza_cardiaca': '0',
#                        'frequenza_respiratoria': '0',
#                        'glicemia': '105 mg/dL',
#                        'pressione_arteriosa': '0',
#                        'pupille_PEARL': 'fisse e non reattive',
#                        'saturazione_ossigeno': '0',
#                        'temperatura': '34.8 °C',
#                        'tempo_rilevazione': '17:56'}],
#  'patologie_pregresse': 'ipertensione',
#  'paziente_consegnato_ps': False,
#  'paziente_rifiuto_trasporto': False,
#  'posizionamento_paziente': 'supino su campo sportivo',
#  'problemi_riscontrati': 'nessuno',
#  'provincia': 'SI',
#  'provincia_nascita': 'SI',
#  'provincia_residenza': 'SI',
#  'relazione_con_paziente': 'amico',
#  'reparto_destinazione': '',
#  'residenza': 'Via delle Rose 2',
#  'ruolo_soccorritore_1': 'autista soccorritore',
#  'ruolo_soccorritore_2': 'medico',
#  'ruolo_soccorritore_3': 'soccorritore',
#  'sesso': 'M',
#  'sintomi': ['collasso improvviso', 'assenza battito', 'assenza respiro'],
#  'soluzione_endovenosa': 'NaCl 0.9%',
#  'stato_coscienza': 'incosciente',
#  'telefono_chiamante': '3398877431',
#  'tipo_mezzo': 'MSA',
#  'via': 'Viale dei Platani'}
